# %% [markdown]
# # Exploring outbreaks in India using geopandas
#
# ## Outline
#
# In this notebook, the outbreaks of different diseases in India will be explored. Outbreak data by district is merged with the geospatial information of each district to map outbreaks. Furthermore the time evolution of outbreaks can also be mapped.
#
#
# ## Background
#
# Disease outbreak data for India was downloaded from the [Integrated Disease Surveillance Program](https://idsp.nic.in/) in the form of weekly reports in .pdf format. The dataset spans 2009 to present day and is extracted from the .pdf files using `idsp_parser.py`. It is then merged with district data from [Global Administrative Area Maps](https://gadm.org) to form a _master_ geopandas dataframe which has all the information for plotting.

# %%
import geopandas as gpd
import pandas as pd
import random
import matplotlib.pyplot as plt
import scipy as sp
from datetime import datetime
import shapely as sh
# %matplotlib notebook

df = pd.read_csv("/users/rsg/anla/podcast/country_disease_outbreaks/india/idsp_reporting/IDSP_data.csv")
df_1 = df.copy()
IND_2 = gpd.read_file("/data/datasets/Projects/PODCAST/country_district_shape_files/INDIA/gadm36_IND_2.shp")

# %% [markdown]
# # Cleaning up the data
#
# The IDSP_parser.py program returns a .csv file of outbreaks. However, further processing is required to clean the dataset. These steps are:
#
# * Consolidate duplicated reporting
# * Convert string columns to numeric, datetime and other datatypes
# * Merging outbreak DataFrame with GeoDataFrame to connect the outbreak data with geospatial information
#
# After these basic steps are complete, then the data can be queried and plotted.

# %% [markdown]
# ## Converting string to units
#
# start date columns goes to datetime object
#
# cases, deaths columns go to numeric

# %%
df_1[['start_date','report_date']] = df[['start_date','report_date']].apply(lambda x: pd.to_datetime(x, dayfirst=True, errors='coerce'))
df_1[['cases','deaths']] = df[['cases','deaths']].apply(lambda x : pd.to_numeric(x, errors='coerce'))

# %%
df[df['start_date'] == '?'].shape[0]
# Out:
# 30

# %% [markdown]
# ## Duplicates
#
# If an outbreak continues to the next week. A follow up report is common. It will have the same location, disease and date, with revised figures for the total number of cases (I believe). Also post 2016 it will share the ID code of the original report of that outbreak.
#
# The solution is to use:
#
# ```
# DataFrame.Duplicated()
# ```

# %%
df_1 = df_1.sort_values(by='start_date')#.sort_values(by='report_date')

# %%
df_1[df_1.duplicated(subset=['state','district','disease','start_date'], keep='last') == True].shape
# Out:
# (664, 12)

# %% [markdown]
# __There appears to be 664 follow up report duplications.__ This means that we should probably throw away these records. Explore these records

# %%
all_duplicates = df_1[(df_1.disease != '?') & \
     (df_1.duplicated(subset=['state','district','disease','start_date'],
                      keep=False) == True)].sort_values(by=['start_date','cases'])

# %%
all_duplicates[:10]
# Out:
#      Unnamed: 0 ID_code       state  district          disease  cases  deaths  \
# 81           81      []  Tamil Nadu     Salem      Chikungunya    NaN     NaN
# 426         426      []  Tamil Nadu     Salem      Chikungunya    NaN     NaN
# 211         211      []   Rajasthan     Sikar          Malaria    NaN     NaN
# 212         212      []   Rajasthan     Sikar          Malaria    NaN     NaN
# 241         241      []      Kerala  Kottayam   Food Poisoning    NaN     NaN
# 259         259      []      Kerala  Kottayam   Food Poisoning    NaN     NaN
# 261         261      []      Kerala  Kottayam  Viral Hepatitis    NaN     NaN
# 300         300      []      Kerala  Kottayam  Viral Hepatitis    NaN     NaN
# 469         469      []      Kerala  Kottayam  Viral Hepatitis    NaN     NaN
# 505         505      []      Kerala  Kottayam  Viral Hepatitis    NaN     NaN
#
#     start_date report_date                  status comments  \
# 81  2009-07-15         NaT  ['Under Surveillance']        ?
# 426 2009-07-15  2009-07-20       ['Under Control']        ?
# 211 2009-09-28         NaT   ['Under observation']        ?
# 212 2009-09-28         NaT       ['Under control']        ?
# 241 2009-11-01  2009-11-02  ['Under surveillance']        ?
# 259 2009-11-01         NaT       ['Under control']        ?
# 261 2009-11-10  2009-11-12  ['Under surveillance']        ?
# 300 2009-11-10         NaT  ['Under surveillance']        ?
# 469 2010-03-05  2010-03-10  ['Under surveillance']        ?
# 505 2010-03-05         NaT       ['Under control']        ?
#
#                                                    raw
# 81   done. 4. Tamil Nadu Salem Chikungunya  67 / 0 ...
# 426  and food hygiene. Salem vii. ?Chikungunya  24 ...
# 211  taken 1. Assam Barpeta xi. Cholera  640 / 12 2...
# 212  area. 2. Rajasthan Sikar xii. Malaria  50 / 4 ...
# 241  5. Kerala Kottayam vi. Food Poisoning  80 / 0 ...
# 259  1 Kerala Kottayam xiii. Food Poisoning  189 / ...
# 261  Kottayam ii. Viral Hepatitis - A  9 / 1 10.11....
# 300  Comments/ Action taken Kottayam Viral Hepatiti...
# 469  taken Kerala Kottayam vii. Viral Hepatitis  9 ...
# 505  Andhra Pradesh Mahabubnagar Acute Diarrhoeal D...

# %% [markdown]
# Lets explore these datasets. _outbreaks_ has text information regarding outbreaks; when, where, what, how many and current status. There is also a comments field which contains potentially useful but unstructured data.

# %% [markdown]
# Count the rows with the same ID_code.

# %%
outbreaks[outbreaks.duplicated('ID_code') == False].set_index(['state','district']).count()
# Out:
# Unnamed: 0     6945
# ID_code        6945
# disease        6945
# cases          6945
# deaths         6945
# start_date     6945
# report_date    6945
# status         6945
# comments       6945
# raw            6945
# dtype: int64

# %%
outbreaks[outbreaks.duplicated('cases',keep=False) == False]#.groupby(['state','district']).count()
# Out:
#        Unnamed: 0                  ID_code             state  \
# 82             82                       []     Daman and Diu
# 3423         3423                       []    Madhya Pradesh
# 3460         3460                       []     Uttar Pradesh
# 3591         3591                       []         Rajasthan
# 3617         3617                       []       Maharashtra
# ...           ...                      ...               ...
# 16977       16977  ['CH/CHD/2017/35/1276']        Chandigarh
# 17004       17004  ['WB/MLD/2017/38/1394']     Daman and Diu
# 17065       17065  ['WB/NCP/2017/44/1558']       West Bengal
# 17096       17096  ['MH/AGB/2017/46/1591']       Maharashtra
# 17116       17116  ['HP/KNG/2017/47/1612']  Himachal Pradesh
#
#                 district                  disease cases deaths start_date  \
# 82                 Daman                        ?  2009    124          ?
# 3423               Satna          Viral Hepatitis   560      0   05-03-12
# 3460              Meerut           Food Poisoning   303      0   03-03-12
# 3591           Dungarpur          Viral Hepatitis   322      0   04-04-12
# 3617              Wardha           Food Poisoning   550      0   17-04-12
# ...                  ...                      ...   ...    ...        ...
# 16977         Chandigarh                   Dengue   327     00   07-08-17
# 17004              Daman              Chikungunya   735     00   09-07-17
# 17065  North 24 Parganas                   Dengue  1305     00   21-09-17
# 17096         Aurangabad                  Cholera  5825     00   10-11-17
# 17116             Kangra  Acute Diarrheal Disease   302     00   20-11-17
#
#       report_date                                             status comments  \
# 82              ?                                                 []        ?
# 3423     06-03-12                                  ['Under control']        ?
# 3460            ?                                  ['Under Control']        ?
# 3591     04-04-12                                  ['Under control']        ?
# 3617     17-04-12                                  ['Under Control']        ?
# ...           ...                                                ...      ...
# 16977           ?                             ['Under Surveillance']        ?
# 17004           ?                             ['Under Surveillance']        ?
# 17065           ?  ['Under Surveillance', 'Under Barachapa', 'Und...        ?
# 17096    13-11-17                             ['Under Surveillance']        ?
# 17116    22-11-17                             ['Under Surveillance']        ?
#
#                                                      raw
# 82     2008 and 2009 124 34 6  27 8 32 18 10  13 18 3...
# 3423   of cases Mandsaur xi Viral Hepatitis?  560 0 0...
# 3460   Uttar Pradesh Meerut xxviii Food Poisoning  30...
# 3591   Rajasthan Dungarpur xvii Acute Diarrhoeal Dise...
# 3617   7. Maharashtra Wardha xv Food Poisoning  550 0...
# ...                                                  ...
# 16977  CH/CHD/2017/35/1276 Chandigarh Dengue 327 00 0...
# 17004  WB/MLD/2017/38/1394 Malda Dengue and Chikungun...
# 17065  WB/NCP/2017/44/1558 West Bengal North 24 Parag...
# 17096  MH/AGB/2017/46/1591 Maharashtra Aurangabad Cho...
# 17116  HP/KNG/2017/47/1612 Himachal Pradesh Kangra Ac...
#
# [217 rows x 12 columns]

# %% [markdown]
# __ISSUE:__ The post 2016 records with codified ID_codes are easy to find followup reports for. However the pre 2016 records reuse the serial numbers each week resulting in a 100s of repeats. This could be solved only recording propper ID codes in the ID code column. Also a more sophisticated matching routine could be used to find same day same disease same location and use that... We could also retrospectively generate ID codes for the pre 2016 records, which could be neat.

# %% [markdown]
# Any value which was not found when creating the dataframe has been replaced with a ?. One way to handle this is to drop all records that contain? Another is to go through and format the columnns correctly. The latter is better as it carries more information.
#
# We would like to
#
# * Make the cases and deaths field to integer
# * Make the dates into datatime object
#
# Using `apply` apply the `.to_numeric()` method along the case and death columns. Errors are coerced, meaning failure results in a NAN value which is then dropped. `lambda` function is used here in order to set the errors='coerce'.

# %%
outbreaks[['cases','deaths']] = outbreaks[['cases','deaths']].apply(lambda x : pd.to_numeric(x, errors='coerce'))

# %% [markdown]
# similarly `apply` `to_datetime` to convert the dates.

# %%
outbreaks[['start_date','report_date']] = outbreaks[['start_date','report_date']].apply(lambda x: pd.to_datetime(x, errors='ignore'))

# %%
outbreaks.start_date[0]
# Out:
# '?'

# %% [markdown]
# ## Adding the geospatial element
#
# There are a few ways we can connect the outbreak data with the region map of India.

# %% [markdown]
# IND_3 is a geopandas, geodataframe which has shape file geometry for the administrative regions of India. As per the following convention,
#
#  * NAME_1 is the state
#  * NAME_2 is the district
#  * NAME_3 is the city

# %%
IND_2
# Out:
#     GID_0 NAME_0     GID_1               NAME_1 NL_NAME_1        GID_2  \
# 0     IND  India   IND.1_1  Andaman and Nicobar      None    IND.1.1_1
# 1     IND  India   IND.1_1  Andaman and Nicobar      None    IND.1.2_1
# 2     IND  India   IND.1_1  Andaman and Nicobar      None    IND.1.3_1
# 3     IND  India   IND.2_1       Andhra Pradesh      None    IND.2.1_1
# 4     IND  India   IND.2_1       Andhra Pradesh      None    IND.2.2_1
# ..    ...    ...       ...                  ...       ...          ...
# 661   IND  India  IND.36_1          West Bengal      None  IND.36.16_1
# 662   IND  India  IND.36_1          West Bengal      None  IND.36.17_1
# 663   IND  India  IND.36_1          West Bengal      None  IND.36.18_1
# 664   IND  India  IND.36_1          West Bengal      None  IND.36.19_1
# 665   IND  India  IND.36_1          West Bengal      None  IND.36.20_1
#
#                        NAME_2             VARNAME_2 NL_NAME_2    TYPE_2  \
# 0             Nicobar Islands                  None      None  District
# 1    North and Middle Andaman                  None      None  District
# 2               South Andaman                  None      None  District
# 3                   Anantapur  Anantpur, Ananthapur      None  District
# 4                    Chittoor       Chitoor|Chittor      None  District
# ..                        ...                   ...       ...       ...
# 661        Pashchim Medinipur     Paschim Medinipur      None  District
# 662           Purba Medinipur       Purba Medinipur      None  District
# 663                  Puruliya                  None      None  District
# 664         South 24 Parganas                  None      None  District
# 665            Uttar Dinajpur                  None      None  District
#
#     ENGTYPE_2  CC_2    HASC_2  \
# 0    District  None  IN.AN.NI
# 1    District  None  IN.AN.NM
# 2    District  None  IN.AN.SA
# 3    District  None  IN.AD.AN
# 4    District  None  IN.AD.CH
# ..        ...   ...       ...
# 661  District  None  IN.WB.WM
# 662  District  None  IN.WB.EM
# 663  District  None  IN.WB.PU
# 664  District  None  IN.WB.PS
# 665  District  None  IN.WB.UD
#
#                                               geometry
# 0    MULTIPOLYGON (((93.78773 6.85264, 93.78849 6.8...
# 1    MULTIPOLYGON (((92.93898 12.22386, 92.93916 12...
# 2    MULTIPOLYGON (((92.47972 10.52056, 92.47945 10...
# 3    POLYGON ((77.71420 13.76079, 77.71314 13.75074...
# 4    POLYGON ((78.46293 12.63537, 78.46190 12.63228...
# ..                                                 ...
# 661  POLYGON ((87.22874 21.95608, 87.22562 21.95712...
# 662  MULTIPOLYGON (((87.98972 22.21750, 87.99028 22...
# 663  POLYGON ((85.88916 23.15176, 85.88641 23.15335...
# 664  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# 665  MULTIPOLYGON (((88.45434 25.66317, 88.45428 25...
#
# [666 rows x 14 columns]

# %% [markdown]
# Most of the data columns in the IND_2 geodataframe are not populated and therefore not helpful.
#
# ## Quick plot

# %%
IND_2.plot()

# %% [markdown]
# The two data frames can be merged using the dataframe method `.merge()`. By merging the two, we can attach the shape file for the district to the outbreaks in that district.
#
# In this case we are interested in the _state_ and _district_ columns because that is the highest resolution the outbreak dataframe has. State must be included because some districts share the same name but are located in different states.

# %% [markdown]
# To do this _NAME\_1_ and _NAME\_2_ are renamded to _state_ and _district_ for compatibility with the outbreak dataframe. Next the multiple level 3 (settlements) data is removed. The dissolve method deals with multiple rows with the same district, keeping the geometry of the first row with a given district.

# %%
district_locations = IND_2[['NAME_1','NAME_2','geometry']]\
                    .rename(columns={'NAME_1':'state','NAME_2':'district'})\
                    .dissolve(by=['state','district'],aggfunc='first')

# %%
district_locations
# Out:
#                                                                                        geometry
# state               district
# Andaman and Nicobar Nicobar Islands           MULTIPOLYGON (((93.78773 6.85264, 93.78849 6.8...
#                     North and Middle Andaman  MULTIPOLYGON (((92.93898 12.22386, 92.93916 12...
#                     South Andaman             MULTIPOLYGON (((92.47972 10.52056, 92.47945 10...
# Andhra Pradesh      Anantapur                 POLYGON ((77.71420 13.76079, 77.71314 13.75074...
#                     Chittoor                  POLYGON ((78.46293 12.63537, 78.46190 12.63228...
# ...                                                                                         ...
# West Bengal         Pashchim Medinipur        POLYGON ((87.22874 21.95608, 87.22562 21.95712...
#                     Purba Medinipur           MULTIPOLYGON (((88.03139 22.06056, 88.03139 22...
#                     Puruliya                  POLYGON ((85.88916 23.15176, 85.88641 23.15335...
#                     South 24 Parganas         MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
#                     Uttar Dinajpur            MULTIPOLYGON (((88.45732 25.59600, 88.45847 25...
#
# [666 rows x 1 columns]

# %%
IND_2[IND_2.NAME_1 == 'Kerala'].set_index('NAME_2').loc[['Alappuzha','Ernakulam','Kottayam']][['geometry']]
# Out:
#                                                     geometry
# NAME_2
# Alappuzha  MULTIPOLYGON (((76.41431 9.56320, 76.41431 9.5...
# Ernakulam  MULTIPOLYGON (((76.38239 9.82431, 76.38264 9.8...
# Kottayam   MULTIPOLYGON (((76.46736 9.54097, 76.46736 9.5...

# %% [markdown]
# This geodataframe contains the unique names and geometry for each district in India. Now it must be merged with the outbreak data along the state and district columns

# %% [markdown]
# ## Plot a random district and label it

# %% [markdown]
# To plot the districts themselves we can use `gpd.plotting.plot_dataframe()`.

# %%
fig, ax = plt.subplots()

# choose a district at random
district = random.choice(district_locations.index)

gpd.plotting.plot_dataframe(district_locations,
                            ax=ax,
                           )
gpd.plotting.plot_polygon_collection(ax, district_locations.loc[[district],'geometry'],
                                     color='red'
                                    )

# district_locations.loc[[district]].centroid
plt.annotate(s=district, xy=(district_locations.loc[[district]].centroid.x,
                             district_locations.loc[[district]].centroid.y
                            )
            )

plt.show()

# %% [markdown]
# # Merge outbreaks with geospatial data on state and district columns

# %%
master = district_locations.merge(outbreaks,on=['state','district'])

# %%
set(master.disease)
# Out:
# {'?',
#  'Acute Diarrheal Disease',
#  'Acute Encephalitis Syndrome',
#  'Acute Flaccid Paralysis',
#  'Acute Respiratory Infection',
#  'Bacillary Dysentery',
#  'Chicken Pox',
#  'Chikungunya',
#  'Cholera',
#  'Dengue',
#  'Diphtheria',
#  'Dog Bite',
#  'Enteric Fever',
#  'Food Poisoning',
#  'Leptospirosis',
#  'Malaria',
#  'Measles',
#  'Meningitis',
#  'Pertussis',
#  'Viral Hepatitis'}

# %%
# %matplotlib notebook

# %%
master[(master.disease ==  'Cholera')].plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# save to file for later use

# %%
master.to_file("IND_outbreaks.shp")

# %% [markdown]
# # Combination of data sets to map outbreaks

# %% [markdown]
# ## Plot Cholera outbreaks

# %% [markdown]
# Lets plot the total cholera outbreaks. To do this we select the outbreaks that are cholera. Then take only the district and cases field before merging with the district locations. Now we have a composite dataframe that can make

# %%
set(outbreaks.disease)

# %%
pwd
# Out:
# '/users/rsg/anla/code/idsp_converter'

# %%
district_locations.merge(
    outbreaks[outbreaks['disease'] == 'Cholera'],
    on=['state','district']
).to_file('./IDSP_cholera_outbreaks_india_2009_to_2016_geopandas.shp')

# %%
test = gpd.read_file('./IDSP_cholera_outbreaks_india_2009_to_2016_geopandas.shp')

# %%
test
# Out:
#               state        district  Unnamed_ 0                 ID_code  \
# 0    Andhra Pradesh   West Godavari        5949                      []
# 1             Assam         Barpeta         210                      []
# 2             Assam          Cachar       10736  ['AS/CCR/2016/3/0048']
# 3             Assam          Cachar       10786  ['AS/CCR/2016/4/0098']
# 4             Assam          Cachar       11995  ['AS/CCR/2016/6/0199']
# ..              ...             ...         ...                     ...
# 678     West Bengal  Uttar Dinajpur        6705                      []
# 679     West Bengal  Uttar Dinajpur        7809                      []
# 680     West Bengal  Uttar Dinajpur        7980                      []
# 681     West Bengal  Uttar Dinajpur        9660                      []
# 682     West Bengal  Uttar Dinajpur       10024                      []
#
#      disease  cases  deaths start_date report_dat                  status  \
# 0    Cholera   14.0     0.0   27-08-13   01-09-13       ['Under control']
# 1    Cholera    NaN     NaN   11-10-09   13-10-09  ['Under surveillance']
# 2    Cholera    2.0     0.0   20-01-16   25-01-16  ['Under Surveillance']
# 3    Cholera  172.0     2.0   27-01-16   27-01-16  ['Under Surveillance']
# 4    Cholera   16.0     0.0   09-02-16   12-02-16       ['Under Control']
# ..       ...    ...     ...        ...        ...                     ...
# 678  Cholera  195.0     2.0   13-01-13          ?       ['Under control']
# 679  Cholera   23.0     0.0   30-09-14   01-10-14  ['Under Surveillance']
# 680  Cholera  102.0     0.0   12-11-14   14-11-14       ['Under Control']
# 681  Cholera   44.0     2.0   30-08-15          ?       ['Under Control']
# 682  Cholera   28.0     1.0   01-12-15   05-12-15       ['Under Control']
#
#     comments                                                raw  \
# 0          ?  1. Andhra Pradesh Nalgonda i Fever  14 0 27/08...
# 1          ?  Dakshin Dinajpur x. Acute Diarrhoeal Disease  ...
# 2          ?  AS/CCR/2016/3/0048 Assam Cachar Cholera 02 00 ...
# 3          ?  AS/CCR/2016/4/0098 Assam Cachar Cholera 172 02...
# 4          ?  AS/CCR/2016/6/0199 Assam Cachar Cholera (Class...
# ..       ...                                                ...
# 678        ?  taken 5. West Bengal Purulia xxiii.Cholera  19...
# 679        ?  West Bengal Dakshin Dinajpur xxii. Cholera?  2...
# 680        ?  Uttar Pradesh Pratapgarh xxvii. Food poisoning...
# 681        ?  10. Uttar Pradesh Shravasti xlvii. Fever  44 0...
# 682        ?  14. Uttar Pradesh Deoria xiv. Chickenpox  28 0...
#
#                                               geometry
# 0    POLYGON ((81.81902 16.66214, 81.83632 16.64615...
# 1    POLYGON ((91.29124 26.57613, 91.29190 26.57254...
# 2    POLYGON ((92.76520 24.52085, 92.76350 24.52147...
# 3    POLYGON ((92.76520 24.52085, 92.76350 24.52147...
# 4    POLYGON ((92.76520 24.52085, 92.76350 24.52147...
# ..                                                 ...
# 678  MULTIPOLYGON (((88.45732 25.59600, 88.45847 25...
# 679  MULTIPOLYGON (((88.45732 25.59600, 88.45847 25...
# 680  MULTIPOLYGON (((88.45732 25.59600, 88.45847 25...
# 681  MULTIPOLYGON (((88.45732 25.59600, 88.45847 25...
# 682  MULTIPOLYGON (((88.45732 25.59600, 88.45847 25...
#
# [683 rows x 13 columns]

# %%
ls
# Out:
#  cleaning_and_merging_outbreaks_with_geospatial.ipynb
# 'Create of dict with state keys and list of districts values.ipynb'
#  disease_names.txt
#  district_names.txt
#  district_names_v0.txt
#  download_idsp_data.ipynb
#  err_log.txt
#  gadm36_IND_2.cpg
#  gadm36_IND_2.dbf
#  gadm36_IND_2.prj
#  gadm36_IND_2.shp
#  gadm36_IND_2.shx
#  IDSP_cholera_outbreaks_india_2009_to_2016_geopandas.cpg
#  IDSP_cholera_outbreaks_india_2009_to_2016_geopandas.dbf
#  IDSP_cholera_outbreaks_india_2009_to_2016_geopandas.prj
#  IDSP_cholera_outbreaks_india_2009_to_2016_geopandas.shp
#  IDSP_cholera_outbreaks_india_2009_to_2016_geopandas.shx
#  IDSP_data.csv
#  idsp_IVO_kerala_lake.cpg
#  idsp_IVO_kerala_lake.dbf
#  idsp_IVO_kerala_lake.prj
#  idsp_IVO_kerala_lake.shp
#  idsp_IVO_kerala_lake.shx
#  idsp_parser.py
#  IDSP_to_CSV.py
#  IND_outbreaks.cpg
#  IND_outbreaks.dbf
#  IND_outbreaks.prj
#  IND_outbreaks.shp
#  IND_outbreaks.shx
#  outbreak_record_detection.ipynb
#  state_district_dict.csv
#  state_names.txt
#  test_pdfs/
#  VALIDATION.ipynb

# %% [markdown]
# First lets figure out the total number of cholera cases

# %%
outbreaks[outbreaks.disease == 'Cholera'].cases.dropna().sum()

# %% [markdown]
# The district locations are ready to be merged with the outbreak data. In this case we just need the number of cholera cases so we select those before merging. That gives a consise geodataframe. Note that the geodataframe should be the one calling the merge() method, otherwise the result will be a normal dataframe, and loose its geo prefix and special abilities. This can be rectified it is just not quite so pleasing.

# %%
composite = district_locations.merge(
    outbreaks[outbreaks['disease'] == 'Acute Diarrheal Disease'][['state','district','cases']],
    on=['state','district']
)
print(type(composite))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %% [markdown]
# drop nan values and aggregate using .dissolve(). This gives us a single row for each district that contains the geometry and number of cases of cholera only.

# %%
composite
# Out:
#                     state        district  \
# 0     Andaman and Nicobar   South Andaman
# 1          Andhra Pradesh        Chittoor
# 2          Andhra Pradesh        Chittoor
# 3          Andhra Pradesh        Chittoor
# 4          Andhra Pradesh        Chittoor
# ...                   ...             ...
# 2280          West Bengal  Uttar Dinajpur
# 2281          West Bengal  Uttar Dinajpur
# 2282          West Bengal  Uttar Dinajpur
# 2283          West Bengal  Uttar Dinajpur
# 2284          West Bengal  Uttar Dinajpur
#
#                                                geometry  cases
# 0     MULTIPOLYGON (((92.47972 10.52056, 92.47945 10...    8.0
# 1     POLYGON ((78.46293 12.63537, 78.46190 12.63228...   30.0
# 2     POLYGON ((78.46293 12.63537, 78.46190 12.63228...   21.0
# 3     POLYGON ((78.46293 12.63537, 78.46190 12.63228...   12.0
# 4     POLYGON ((78.46293 12.63537, 78.46190 12.63228...   35.0
# ...                                                 ...    ...
# 2280  MULTIPOLYGON (((88.45732 25.59600, 88.45847 25...   11.0
# 2281  MULTIPOLYGON (((88.45732 25.59600, 88.45847 25...   26.0
# 2282  MULTIPOLYGON (((88.45732 25.59600, 88.45847 25...   72.0
# 2283  MULTIPOLYGON (((88.45732 25.59600, 88.45847 25...   27.0
# 2284  MULTIPOLYGON (((88.45732 25.59600, 88.45847 25...   19.0
#
# [2285 rows x 4 columns]

# %%
cholera_district_cases = composite.dropna().dissolve(by=['state','district'],aggfunc='sum')
print(type(cholera_district_cases))
print(cholera_district_cases.sum())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# cases    108748.0
# dtype: float64

# %%
# %matplotlib notebook

# %%
fig, ax = plt.subplots(figsize=(5,5),dpi=150)

IND_2.plot(ax=ax,
           color='white',
           edgecolor='black',
           alpha=1,
           linewidth=0.05,
          )

cholera_district_cases.plot(column = 'cases',
                            cmap='Reds',
                            ax=ax,
                            legend=True,
                           )

plt.title('Cholera cases 2009-present')

# label the 3 most infected districts
for index in cholera_district_cases.nlargest(3,columns='cases').index:
    gpd.plotting.plot_point_collection(ax,
                                       cholera_district_cases.loc[[index]].centroid,
#                                        color='black',
                                       marker='+',
                                       label=" ".join(index)+": "+str(cholera_district_cases.loc[[index]].cases.sum())
                                      )
    
#     plt.annotate(s= " ".join(index),
#                  xy=(cholera_district_cases.loc[[index]].centroid.x,
#                      cholera_district_cases.loc[[index]].centroid.y),
#                  horizontalalignment='left',
#                  verticalalignment='bottom'
#                 )

# get the total bounding box
x0,y0,x1,y1 = cholera_district_cases.total_bounds

# display total cases as an inset
plt.text(x0 + 1  * (x1-x0),
         y0 + 1  * (y1-y0),
         'total cases = '+str(int(cholera_district_cases.cases.sum())),
         horizontalalignment='right',
        )

# plt.legend(loc=1)

plt.tight_layout()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="749.9999837441882">

# %% [markdown]
# Heatmap showing total Cholera cases by district from 2009 - present. The results with later version of the data analysis code seems to produce wildly different results. Which isn't reassuring. A ground truth metric against which the data can be compared would be very useful!

# %% [markdown]
# At this point we have some informative data. However it should be noted that this representation shows the total number of outbreaks by district. The districts themselves are not equal and this graphic shows neither the spatial density of cholera nor the infection rate.

# %%
cholera_state_cases = cholera_district_cases.dissolve(by='state',aggfunc='sum')

# %%
cholera_state_cases

# %%
d[(d['x']>2) & (d['y']>7)]

# %%
mah_cholera = outbreaks[(outbreaks['state'] == 'Maharashtra') & (outbreaks.disease == 'Cholera')]

# %%
mah_cholera[['district','cases','start_date']]

# %%
outbreaks.loc[8801].raw

# %%
master[(master['state'] == 'Kerala') & \
       (master['disease'] == ('Cholera' or 'Acute Diarrheal Disease' or 'Food Poisoning'))].to_file('idsp_IVO_kerala_lake.shp')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-211bae505a13> in <module>
#       1 master[(master['state'] == 'Kerala') & \
# ----> 2        (master['disease'] == (['Cholera','Acute Diarrheal Disease' ,'Food Poisoning']))].to_file('idsp_IVO_kerala_lake.shp')
#
# ~/anaconda3/envs/geospatial/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1205             # as it will broadcast
#    1206             if other.ndim != 0 and len(self) != len(other):
# -> 1207                 raise ValueError("Lengths must match to compare")
#    1208
#    1209             res_values = na_op(self.values, np.asarray(other))
#
# ValueError: Lengths must match to compare

# %%
test_kerala_lake = gpd.read_file('idsp_IVO_kerala_lake.shp')

# %%
set(test_kerala_lake.disease)
# Out:
# {'Cholera'}

# %%
# !cp idsp_IVO* /data/datasets/Projects/REVIVAL/disease_data/
